# %%
import pandas as pd

# %%
retail_data = pd.read_csv("Online Retail.csv")

# %%
retail_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 135979    547921     20728                  LUNCH BAG CARS BLUE      10.0
# 135980    547921     22993         SET OF 4 PANTRY JELLY MOULDS      12.0
# 135981    547921     23050          RECYCLED ACAPULCO MAT GREEN       2.0
# 135982    547921     23052      RECYCLED ACAPULCO MAT TURQUOISE       2.0
# 135983     54792       NaN                                  NaN       NaN
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
retail_data.describe()
# Out:
#             Quantity      UnitPrice    CustomerID
# count  135983.000000  135983.000000  93013.000000
# mean        8.867197       5.186160  15287.256459
# std       289.925731     106.883301   1739.434562
# min    -74215.000000       0.000000  12346.000000
# 25%         1.000000       1.250000  13859.000000
# 50%         3.000000       2.460000  15179.000000
# 75%        10.000000       4.210000  16875.000000
# max     74215.000000   16888.020000  18283.000000

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135984 entries, 0 to 135983
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    135984 non-null  object
#  1   StockCode    135983 non-null  object
#  2   Description  135579 non-null  object
#  3   Quantity     135983 non-null  float64
#  4   InvoiceDate  135983 non-null  object
#  5   UnitPrice    135983 non-null  float64
#  6   CustomerID   93013 non-null   float64
#  7   Country      135983 non-null  object
# dtypes: float64(3), object(5)
# memory usage: 8.3+ MB

# %%
retail_data["TotalPrice"] = retail_data.apply(lambda row: row["Quantity"] * row["UnitPrice"], axis=1)

# %%
retail_data["TotalPrice"] = retail_data.apply(lambda x : x["Quantity"] * x["UnitPrice"] ,axis=1)

# %%
retail_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 135979    547921     20728                  LUNCH BAG CARS BLUE      10.0
# 135980    547921     22993         SET OF 4 PANTRY JELLY MOULDS      12.0
# 135981    547921     23050          RECYCLED ACAPULCO MAT GREEN       2.0
# 135982    547921     23052      RECYCLED ACAPULCO MAT TURQUOISE       2.0
# 135983     54792       NaN                                  NaN       NaN
#
#              InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# ...

# %%
retail_data_f = retail_data[retail_data['TotalPrice']>1000]
retail_data_f.head()
# Out:
#      InvoiceNo StockCode                     Description  Quantity  \
# 870     536477     21137        BLACK RECORD COVER FRAME     480.0
# 2364    536584    84029E  RED WOOLLY HOTTIE WHITE HEART.     384.0
# 4505    536785     22423        REGENCY CAKESTAND 3 TIER     144.0
# 4850    536809     84950  ASSORTED COLOUR T-LIGHT HOLDER    1824.0
# 4946    536830     21915          RED  HARMONICA IN BOX     1400.0
#
#            InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 870   01/12/2010 12:27       3.39     16210.0  United Kingdom      1627.2
# 2364  01/12/2010 16:22       2.95     13777.0  United Kingdom      1132.8
# 4505  02/12/2010 15:22      10.95     15061.0  United Kingdom      1576.8
# 4850  02/12/2010 16:48       0.55     15299.0  United Kingdom      1003.2
# 4946  02/12/2010 17:38       1.06     16754.0  United Kingdom      1484.0

# %%
retail_data.sort_values(by="TotalPrice",ascending=False).head()
# Out:
#       InvoiceNo  StockCode                         Description  Quantity  \
# 61619    541431      23166      MEDIUM CERAMIC TOP STORAGE JAR   74215.0
# 15017    537632  AMAZONFEE                          AMAZON FEE       1.0
# 52711    540815      21108  FAIRY CAKE FLANNEL ASSORTED COLOUR    3114.0
# 52709    540815     85123A  WHITE HANGING HEART T-LIGHT HOLDER    1930.0
# 52772    540818      48185                  DOORMAT FAIRY CAKE     670.0
#
#             InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 61619  18/01/2011 10:01       1.04     12346.0  United Kingdom    77183.60
# 15017  07/12/2010 15:08   13541.33         NaN  United Kingdom    13541.33
# 52711  11/01/2011 12:55       2.10     15749.0  United Kingdom     6539.40
# 52709  11/01/2011 12:55       2.55     15749.0  United Kingdom     4921.50
# 52772  11/01/2011 12:57       6.75     15749.0  United Kingdom     4522.50

# %%
retail_data.groupby("Country").agg({"Quantity" : "sum", "TotalPrice" :"sum"}).sort_values(by="TotalPrice",ascending=False).head()
# Out:
#                 Quantity  TotalPrice
# Country
# United Kingdom  985430.0  1964372.95
# Netherlands      45022.0    60689.70
# EIRE             28580.0    58452.29
# Germany          26293.0    52385.03
# France           24724.0    44440.65

# %%
retail_data.groupby("CustomerID")["TotalPrice"].sum("TotalPrice").sort_values(by="TotalPrice",ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3047073722.py in <cell line: 0>()
# ----> 1 retail_data.groupby("CustomerID")["TotalPrice"].sum("TotalPrice").sort_values(by="TotalPrice",ascending=False)
#
# TypeError: Series.sort_values() got an unexpected keyword argument 'by'

# %%
retail_data.groupby("CustomerID")["TotalPrice"].sum().sort_values(ascending=False).head()
# Out:
# CustomerID
# 14646.0    59228.88
# 18102.0    45279.41
# 12415.0    37674.04
# 17450.0    33017.46
# 14156.0    32935.62
# Name: TotalPrice, dtype: float64

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135984 entries, 0 to 135983
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    135984 non-null  object
#  1   StockCode    135983 non-null  object
#  2   Description  135579 non-null  object
#  3   Quantity     135983 non-null  float64
#  4   InvoiceDate  135983 non-null  object
#  5   UnitPrice    135983 non-null  float64
#  6   CustomerID   93013 non-null   float64
#  7   Country      135983 non-null  object
#  8   TotalPrice   135983 non-null  float64
# dtypes: float64(4), object(5)
# memory usage: 9.3+ MB

# %%
retail_data["InvoiceDate"] = pd.to_datetime(retail_data["InvoiceDate"], format="%d/%m/%Y %H:%M", dayfirst=True)

# %%
retail_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135984 entries, 0 to 135983
# Data columns (total 9 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    135984 non-null  object
#  1   StockCode    135983 non-null  object
#  2   Description  135579 non-null  object
#  3   Quantity     135983 non-null  float64
#  4   InvoiceDate  135983 non-null  datetime64[ns]
#  5   UnitPrice    135983 non-null  float64
#  6   CustomerID   93013 non-null   float64
#  7   Country      135983 non-null  object
#  8   TotalPrice   135983 non-null  float64
# dtypes: datetime64[ns](1), float64(4), object(4)
# memory usage: 9.3+ MB

# %%
retail_data["invoice_month"] = retail_data["InvoiceDate"].dt.month.astype("Int64")

# %%
retail_data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    invoice_month
# 0             12
# 1             12
# 2             12
# 3             12
# 4             12

# %%
retail_data["invoice_month"].value_counts()
# Out:
# invoice_month
# 12    42481
# 1     35147
# 3     30648
# 2     27707
# Name: count, dtype: Int64

# %%
retail_data.groupby("invoice_month")["InvoiceNo"].count()
# Out:
# invoice_month
# 1     35147
# 2     27707
# 3     30648
# 12    42481
# Name: InvoiceNo, dtype: int64

# %%
retail_data.groupby("invoice_month")["InvoiceNo"].nunique()
# Out:
# invoice_month
# 1     1476
# 2     1393
# 3     1631
# 12    2025
# Name: InvoiceNo, dtype: int64

# %%
txn_per_month = (
    retail_data.groupby("invoice_month")["InvoiceNo"]
    .nunique()
    .reset_index(name="transaction_count")
)

print(txn_per_month)
# Out:
#    invoice_month  transaction_count
# 0              1               1476
# 1              2               1393
# 2              3               1631
# 3             12               2025

# %%
retail_data[(retail_data["Country"]=="United Kingdom") & (retail_data["Quantity"]>=0)].head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1    536365     71053                  WHITE METAL LANTERN       6.0
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
#
#    invoice_month
# 0             12
# 1             12
# 2             12
# 3             12
# 4             12

# %%
retail_data.groupby("Country")["Country"].value_counts().sort_values(ascending=False).head()
# Out:
# Country
# United Kingdom    125157
# Germany             2266
# France              2018
# EIRE                1561
# Spain                759
# Name: count, dtype: int64

# %%
retail_data["Value_lable"] = retail_data['TotalPrice'].map(lambda x : "High" if x > 500  else 'low')
#<value_if_true> if <condition> else <value_if_false>

# %%
retail_data
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER       6.0
# 1         536365     71053                  WHITE METAL LANTERN       6.0
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER       8.0
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE       6.0
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.       6.0
# ...          ...       ...                                  ...       ...
# 135979    547921     20728                  LUNCH BAG CARS BLUE      10.0
# 135980    547921     22993         SET OF 4 PANTRY JELLY MOULDS      12.0
# 135981    547921     23050          RECYCLED ACAPULCO MAT GREEN       2.0
# 135982    547921     23052      RECYCLED ACAPULCO MAT TURQUOISE       2.0
# 135983     54792       NaN                                  NaN       NaN
#
#                InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice  \
# ...
